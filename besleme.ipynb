# %%
import os
import shutil
import time
import random

kaynak_ok = r"C:\Users\safak\OneDrive\Masaüstü\Personal Projects\ML_visual\Veri_Seti\test\ok_front"
kaynak_nok = r"C:\Users\safak\OneDrive\Masaüstü\Personal Projects\ML_visual\Veri_Seti\test\def_front"

# Arayüzün izlediği (kamera) hedef klasörler
hedef_ch1 = r"C:\Users\safak\KAMERA_1_GELEN"
hedef_ch2 = r"C:\Users\safak\KAMERA_2_GELEN"

# Test edilecek toplam parça sayısı
TEST_ADEDI = 100 
BEKLEME_SURESI = 0.3 # İki parça arası bekleme süresi(300 ms)

# DOSYA HAZIRLAMA
ok_dosyalar = [os.path.join(kaynak_ok, f) for f in os.listdir(kaynak_ok) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
nok_dosyalar = [os.path.join(kaynak_nok, f) for f in os.listdir(kaynak_nok) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
tum_dosyalar = ok_dosyalar + nok_dosyalar
random.shuffle(tum_dosyalar)

# İstenen sayıda parçayı al
test_havuzu = tum_dosyalar[:TEST_ADEDI]

print(" ÇİFT KANALLI SANAL BESLEYİCİ ÇALIŞTIRILDI ")
print("-" * 100)
print(f"Toplam {len(test_havuzu)} adet parça (OK/NOK karışık), rastgele CH1 ve CH2'ye veriliyor...\n")

# ÜRETİM BANDI SİMÜLASYONU 
for i, kaynak_yol in enumerate(test_havuzu, 1):
    dosya_adi = os.path.basename(kaynak_yol)
    
    # %50 ihtimalle CH1 veya CH2'yi seç
    hedef_klasor = random.choice([hedef_ch1, hedef_ch2])
    kanal_adi = "CH1" if hedef_klasor == hedef_ch1 else "CH2"
    yeni_dosya_adi = f"simtest_{i}_{dosya_adi}"
    hedef_yol_yeni = os.path.join(hedef_klasor, yeni_dosya_adi)
    shutil.copy(kaynak_yol, hedef_yol_yeni)    
    durum = "OK " if kaynak_yol in ok_dosyalar else "NOK"
    print(f"[{i}/{len(test_havuzu)}] -> {kanal_adi} Bandı | Parça: {durum} | {yeni_dosya_adi}")
    time.sleep(BEKLEME_SURESI) 

print("-" * 100)
print("Test beslemesi tamamlandı! Lütfen uygulamanın log sekmesinden E2E sürelerini inceleyin.")
# Out:
#  ÇİFT KANALLI SANAL BESLEYİCİ ÇALIŞTIRILDI
# ----------------------------------------------------------------------------------------------------
# Toplam 100 adet parça (OK/NOK karışık), rastgele CH1 ve CH2'ye veriliyor...
#
# [1/100] -> CH1 Bandı | Parça: NOK | simtest_1_cast_def_0_662.jpeg
# [2/100] -> CH1 Bandı | Parça: NOK | simtest_2_cast_def_0_1499.jpeg
# [3/100] -> CH1 Bandı | Parça: OK  | simtest_3_cast_ok_0_2769.jpeg
# [4/100] -> CH1 Bandı | Parça: NOK | simtest_4_cast_def_0_4134.jpeg
# [5/100] -> CH2 Bandı | Parça: NOK | simtest_5_cast_def_0_829.jpeg
# [6/100] -> CH1 Bandı | Parça: NOK | simtest_6_cast_def_0_1453.jpeg
# [7/100] -> CH1 Bandı | Parça: NOK | simtest_7_cast_def_0_1685.jpeg
# [8/100] -> CH1 Bandı | Parça: NOK | simtest_8_new__0_9014.jpeg
# [9/100] -> CH1 Bandı | Parça: NOK | simtest_9_cast_def_0_1488.jpeg
# [10/100] -> CH1 Bandı | Parça: NOK | simtest_10_cast_def_0_1359.jpeg
# [11/100] -> CH2 Bandı | Parça: NOK | simtest_11_cast_def_0_3438.jpeg
# [12/100] -> CH1 Bandı | Parça: NOK | simtest_12_cast_def_0_1665.jpeg
# [13/100] -> CH2 Bandı | Parça: OK  | simtest_13_cast_ok_0_9943.jpeg
# [14/100] -> CH1 Bandı | Parça: NOK | simtest_14_cast_def_0_88.jpeg
# [15/100] -> CH2 Bandı | Parça: NOK | simtest_15_cast_def_0_160.jpeg
# [16/100] -> CH2 Bandı | Parça: NOK | simtest_16_cast_def_0_1509.jpeg
# [17/100] -> CH1 Bandı | Parça: NOK | simtest_17_cast_def_0_1895.jpeg
# [18/100] -> CH1 Bandı | Parça: NOK | simtest_18_cast_def_0_1174.jpeg
# [19/100] -> CH2 Bandı | Parça: NOK | simtest_19_cast_def_0_620.jpeg
# [20/100] -> CH2 Bandı | Parça: OK  | simtest_20_cast_ok_0_2698.jpeg
# [21/100] -> CH1 Bandı | Parça: NOK | simtest_21_cast_def_0_2319.jpeg
# [22/100] -> CH1 Bandı | Parça: OK  | simtest_22_cast_ok_0_5805.jpeg
# [23/100] -> CH1 Bandı | Parça: OK  | simtest_23_cast_ok_0_1210.jpeg
# [24/100] -> CH2 Bandı | Parça: NOK | simtest_24_cast_def_0_2102.jpeg
# [25/100] -> CH2 Bandı | Parça: OK  | simtest_25_cast_ok_0_863.jpeg
# [26/100] -> CH2 Bandı | Parça: OK  | simtest_26_cast_ok_0_869.jpeg
# [27/100] -> CH2 Bandı | Parça: NOK | simtest_27_cast_def_0_2376.jpeg
# [28/100] -> CH2 Bandı | Parça: NOK | simtest_28_cast_def_0_2154.jpeg
# [29/100] -> CH1 Bandı | Parça: NOK | simtest_29_cast_def_0_1628.jpeg
# [30/100] -> CH2 Bandı | Parça: NOK | simtest_30_cast_def_0_831.jpeg
# [31/100] -> CH2 Bandı | Parça: NOK | simtest_31_cast_def_0_1613.jpeg
# [32/100] -> CH1 Bandı | Parça: OK  | simtest_32_cast_ok_0_1202.jpeg
# [33/100] -> CH2 Bandı | Parça: NOK | simtest_33_cast_def_0_2212.jpeg
# [34/100] -> CH1 Bandı | Parça: NOK | simtest_34_new__0_6459.jpeg
# [35/100] -> CH1 Bandı | Parça: NOK | simtest_35_cast_def_0_1467.jpeg
# [36/100] -> CH1 Bandı | Parça: NOK | simtest_36_cast_def_0_1392.jpeg
# [37/100] -> CH2 Bandı | Parça: OK  | simtest_37_cast_ok_0_7946.jpeg
# [38/100] -> CH2 Bandı | Parça: NOK | simtest_38_cast_def_0_181.jpeg
# [39/100] -> CH1 Bandı | Parça: NOK | simtest_39_cast_def_0_594.jpeg
# [40/100] -> CH1 Bandı | Parça: OK  | simtest_40_cast_ok_0_7632.jpeg
# [41/100] -> CH2 Bandı | Parça: NOK | simtest_41_cast_def_0_1583.jpeg
# [42/100] -> CH2 Bandı | Parça: OK  | simtest_42_cast_ok_0_1385.jpeg
# [43/100] -> CH2 Bandı | Parça: NOK | simtest_43_cast_def_0_174.jpeg
# [44/100] -> CH1 Bandı | Parça: NOK | simtest_44_cast_def_0_3105.jpeg
# [45/100] -> CH2 Bandı | Parça: NOK | simtest_45_cast_def_0_9969.jpeg
# [46/100] -> CH1 Bandı | Parça: NOK | simtest_46_cast_def_0_3473.jpeg
# [47/100] -> CH1 Bandı | Parça: NOK | simtest_47_cast_def_0_1500.jpeg
# [48/100] -> CH2 Bandı | Parça: OK  | simtest_48_cast_ok_0_1200.jpeg
# [49/100] -> CH1 Bandı | Parça: NOK | simtest_49_cast_def_0_1506.jpeg
# [50/100] -> CH1 Bandı | Parça: OK  | simtest_50_cast_ok_0_9925.jpeg
# [51/100] -> CH1 Bandı | Parça: NOK | simtest_51_new__0_3539.jpeg
# [52/100] -> CH2 Bandı | Parça: NOK | simtest_52_cast_def_0_235.jpeg
# [53/100] -> CH2 Bandı | Parça: OK  | simtest_53_cast_ok_0_2798.jpeg
# [54/100] -> CH2 Bandı | Parça: OK  | simtest_54_cast_ok_0_1145.jpeg
# [55/100] -> CH1 Bandı | Parça: NOK | simtest_55_cast_def_0_2510.jpeg
# [56/100] -> CH1 Bandı | Parça: NOK | simtest_56_cast_def_0_2273.jpeg
# [57/100] -> CH2 Bandı | Parça: NOK | simtest_57_cast_def_0_1638.jpeg
# [58/100] -> CH1 Bandı | Parça: OK  | simtest_58_cast_ok_0_2914.jpeg
# [59/100] -> CH1 Bandı | Parça: NOK | simtest_59_cast_def_0_1269.jpeg
# [60/100] -> CH2 Bandı | Parça: NOK | simtest_60_cast_def_0_2339.jpeg
# [61/100] -> CH1 Bandı | Parça: OK  | simtest_61_cast_ok_0_2754.jpeg
# [62/100] -> CH2 Bandı | Parça: OK  | simtest_62_cast_ok_0_2724.jpeg
# [63/100] -> CH1 Bandı | Parça: NOK | simtest_63_cast_def_0_1528.jpeg
# [64/100] -> CH1 Bandı | Parça: OK  | simtest_64_cast_ok_0_5605.jpeg
# [65/100] -> CH2 Bandı | Parça: NOK | simtest_65_cast_def_0_2215.jpeg
# [66/100] -> CH2 Bandı | Parça: NOK | simtest_66_cast_def_0_1639.jpeg
# [67/100] -> CH1 Bandı | Parça: NOK | simtest_67_cast_def_0_1535.jpeg
# [68/100] -> CH2 Bandı | Parça: OK  | simtest_68_cast_ok_0_1019.jpeg
# [69/100] -> CH2 Bandı | Parça: OK  | simtest_69_cast_ok_0_6365.jpeg
# [70/100] -> CH2 Bandı | Parça: OK  | simtest_70_cast_ok_0_16.jpeg
# [71/100] -> CH1 Bandı | Parça: OK  | simtest_71_cast_ok_0_1381.jpeg
# [72/100] -> CH2 Bandı | Parça: OK  | simtest_72_cast_ok_0_2272.jpeg
# [73/100] -> CH1 Bandı | Parça: OK  | simtest_73_cast_ok_0_1180.jpeg
# [74/100] -> CH1 Bandı | Parça: NOK | simtest_74_cast_def_0_2516.jpeg
# [75/100] -> CH1 Bandı | Parça: OK  | simtest_75_cast_ok_0_2829.jpeg
# [76/100] -> CH2 Bandı | Parça: NOK | simtest_76_cast_def_0_162.jpeg
# [77/100] -> CH1 Bandı | Parça: NOK | simtest_77_cast_def_0_65.jpeg
# [78/100] -> CH1 Bandı | Parça: NOK | simtest_78_cast_def_0_1571.jpeg
# [79/100] -> CH2 Bandı | Parça: NOK | simtest_79_cast_def_0_1399.jpeg
# [80/100] -> CH1 Bandı | Parça: OK  | simtest_80_cast_ok_0_925.jpeg
# [81/100] -> CH2 Bandı | Parça: NOK | simtest_81_cast_def_0_1422.jpeg
# [82/100] -> CH2 Bandı | Parça: OK  | simtest_82_cast_ok_0_3294.jpeg
# [83/100] -> CH1 Bandı | Parça: NOK | simtest_83_cast_def_0_1418.jpeg
# [84/100] -> CH2 Bandı | Parça: NOK | simtest_84_cast_def_0_1633.jpeg
# [85/100] -> CH2 Bandı | Parça: OK  | simtest_85_cast_ok_0_5560.jpeg
# [86/100] -> CH1 Bandı | Parça: NOK | simtest_86_cast_def_0_2553.jpeg
# [87/100] -> CH2 Bandı | Parça: NOK | simtest_87_cast_def_0_1233.jpeg
# [88/100] -> CH1 Bandı | Parça: NOK | simtest_88_cast_def_0_538.jpeg
# [89/100] -> CH1 Bandı | Parça: OK  | simtest_89_cast_ok_0_937.jpeg
# [90/100] -> CH2 Bandı | Parça: OK  | simtest_90_cast_ok_0_7631.jpeg
# [91/100] -> CH1 Bandı | Parça: NOK | simtest_91_cast_def_0_1625.jpeg
# [92/100] -> CH1 Bandı | Parça: NOK | simtest_92_cast_def_0_5302.jpeg
# [93/100] -> CH2 Bandı | Parça: NOK | simtest_93_cast_def_0_669.jpeg
# [94/100] -> CH2 Bandı | Parça: NOK | simtest_94_new__0_3973.jpeg
# [95/100] -> CH2 Bandı | Parça: OK  | simtest_95_cast_ok_0_1368.jpeg
# [96/100] -> CH1 Bandı | Parça: NOK | simtest_96_cast_def_0_9960.jpeg
# [97/100] -> CH1 Bandı | Parça: OK  | simtest_97_cast_ok_0_1209.jpeg
# [98/100] -> CH1 Bandı | Parça: OK  | simtest_98_cast_ok_0_1092.jpeg
# [99/100] -> CH1 Bandı | Parça: NOK | simtest_99_cast_def_0_1661.jpeg
# [100/100] -> CH1 Bandı | Parça: NOK | simtest_100_cast_def_0_1612.jpeg
# ----------------------------------------------------------------------------------------------------
# Test beslemesi tamamlandı! Lütfen uygulamanın log sekmesinden E2E sürelerini inceleyin.
